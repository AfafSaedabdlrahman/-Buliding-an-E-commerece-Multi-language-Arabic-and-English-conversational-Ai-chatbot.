# %% [markdown]
# #Arabic_model

# %% [markdown]
# ### Import libraries

# %%
# !pip install pyarabic
import numpy as np
import pickle
from keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
import pyarabic.araby as araby
import nltk
import pandas as pd
import string
import re
import warnings
warnings.filterwarnings('ignore')
import joblib
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Language detection model

# %%
df = pd.read_csv('Language_detection.csv',error_bad_lines=False)
def removeSymbolsAndNumbers(text):        
        text = re.sub(r'[{}]'.format(string.punctuation), '', text)
        text = re.sub(r'\d+', '', text)
        text = re.sub(r'[@]', '', text)

        return text.lower()

def removeEnglishLetters(text):
    text = re.sub(r'[a-zA-Z]+', '', text)
    return text.lower()


X0 = df.apply(lambda x: removeEnglishLetters(x.Text) if x.Language in ['Arabic']  else x.Text, axis = 1)
X1 = X0.apply(removeSymbolsAndNumbers)
y = df['Language']
x_train, x_test, y_train, y_test = train_test_split(X1,y, random_state=42)

vectorizer = TfidfVectorizer(ngram_range=(1,3), analyzer='char')

pipe = pipeline.Pipeline([
    ('vectorizer', vectorizer),
    ('clf', LogisticRegression())
])

pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('vectorizer',
#                  TfidfVectorizer(analyzer='char', ngram_range=(1, 3))),
#                 ('clf', LogisticRegression())])

# %% [markdown]
# ### Load data and models

# %%
with open('questions_arabic.pkl', 'rb') as f:
   questions_arabic = pickle.load(f)
with open('answers_arabic.pkl', 'rb') as f:
   answers_arabic = pickle.load(f)
with open('questions_English.pkl', 'rb') as f:
   questions = pickle.load(f)
with open('answers_English.pkl', 'rb') as f:
   answers = pickle.load(f)

# %%
enc_model=load_model('Arabic_encoder_model.h5')
dec_model=load_model('Arabic_decoder_model.h5')
enc_model_english=load_model('encoder_model_english3 .h5')
dec_model_english=load_model('decoder_model_english3 .h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
tokenizer =Tokenizer()
tokenizer.fit_on_texts( questions_arabic + answers_arabic )
VOCAB_SIZE = len( tokenizer.word_index )+1
print( 'VOCAB SIZE : {}'.format( VOCAB_SIZE ))

# %%
def normalizeArabic(text):
  text = text.strip()
  text = re.sub("[إأٱآا]", "ا", text)
  text = re.sub("ى", "ي", text)
  text = re.sub("ؤ", "ء", text)
  text = re.sub("ئ", "ء", text)
  text = re.sub("ة", "ه", text)
  text = re.sub("او", "", text)
  noise = re.compile(""" ّ    | # Tashdid
                        َ    | # Fatha
                        ً    | # Tanwin Fath
                        ُ    | # Damma
                        ٌ    | # Tanwin Damm
                        ِ    | # Kasra
                        ٍ    | # Tanwin Kasr
                        ْ    | # Sukun
                        ـ     # Tatwil/Kashida
                    """, re.VERBOSE)
  text = re.sub(noise, '', text)
  text= re.sub('[\\s]+'," ",text) # Remove all spaces
  ## remove extra whitespace
  text = re.sub('\s+', ' ', text)  
  return araby.strip_tashkeel(text)

# %%
maxlen_answers=10
maxlen_questions=18
def str_to_tokens( sentence : str ):
    words =normalizeArabic(sentence).split()
    tokens_list = list()
    for word in words:
        tokens_list.append( tokenizer.word_index[ word ] ) 
    return pad_sequences( [tokens_list] , maxlen=maxlen_questions , padding='post')

# %%
#get the user name
def decode_response(text):
#      for _ in range(encoder_input_data.shape[0]):
        states_values = enc_model.predict(text)
        # states_values = enc_model.predict(text )
        empty_target_seq = np.zeros( ( 1 , 1 ) )
        empty_target_seq[0, 0] = tokenizer.word_index['start']
        stop_condition = False
        decoded_translation = ''
        while not stop_condition :
            dec_outputs , h , c = dec_model.predict([ empty_target_seq ] + states_values )
            sampled_word_index = np.argmax( dec_outputs[0, -1, :] )
            sampled_word = None
            for word , index in tokenizer.word_index.items() :
                if sampled_word_index == index :
                    decoded_translation += ' {}'.format( word )
                    sampled_word = word
    
            if sampled_word == 'end' or len(decoded_translation.split()) > maxlen_answers:
               stop_condition = True
            
            empty_target_seq = np.zeros( ( 1 , 1 ) )  
            empty_target_seq[ 0 , 0 ] = sampled_word_index
            states_values = [ h , c ] 
        return "Bot:" +decoded_translation.replace(' end', '')

# %%
def generate_response(text):
#     text = input("")
    input_matrix = str_to_tokens(text)
    chatbot_response = decode_response(input_matrix)
  #Remove <START> and <END> tokens from chatbot_response
    chatbot_response = chatbot_response.replace("<START>",'')
    chatbot_response = chatbot_response.replace("<END>",'')
    return chatbot_response

# %%
generate_response(" البلوزه رقم 21 كم سعرها")
# Out:
# Enter question :  البلوزه رقم 21 كم سعرها
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 11ms/step
# 'Bot: سعر البلوزه 4000'

# %% [markdown]
# #English_model

# %%
def clean_text(text):
    text = re.sub(r"\s+"," ",str(text)) # to remove white space
    text = re.sub(r"<[^>]+>"," ",str(text)) # remove html tags
    text = re.sub(r"[^A-Za-zÀ-ž-Z0-9'.,]"," ",str(text)) # not clean A-Za-zÀ-ž-Z0-9
    word_tokens = text.split()
    text_clean = " ".join(word_tokens)
    return text_clean
# Out:
# [nltk_data] Downloading package omw-1.4 to C:\Users\Mohamed
# [nltk_data]     Mousa\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
tokenizer_english =Tokenizer()
tokenizer_english.fit_on_texts( questions + answers )
VOCAB_SIZE = len( tokenizer_english.word_index )+1
print( 'VOCAB SIZE : {}'.format( VOCAB_SIZE ))
# Out:
# VOCAB SIZE : 5817

# %%
maxlen_questions_english=15
maxlen_answers_english=80
def str_to_tokens_english( sentence : str ):
    words = clean_text(sentence).split()
    tokens_list = list()
    for word in words:
        tokens_list.append( tokenizer_english.word_index[ word ] ) 
    return pad_sequences( [tokens_list] , maxlen=maxlen_questions_english , padding='post')

# %%
def decode_response_english(text):
  #  for _ in range(encoder_input_data.shape[0]):
        states_values = enc_model_english.predict(text)
        # states_values = enc_model_english.predict(text )
        empty_target_seq = np.zeros( ( 1 , 1 ) )
        empty_target_seq[0, 0] = tokenizer_english.word_index['start']
        stop_condition = False
        decoded_translation = ''
        while not stop_condition :
            dec_outputs , h , c = dec_model_english.predict([ empty_target_seq ] + states_values )
            sampled_word_index = np.argmax( dec_outputs[0, -1, :] )
            sampled_word = None
            for word , index in tokenizer_english.word_index.items() :
                if sampled_word_index == index :
                    decoded_translation += ' {}'.format( word )
                    sampled_word = word
            if sampled_word == 'end' or len(decoded_translation.split()) > maxlen_answers_english:
               stop_condition = True
            
            empty_target_seq = np.zeros( ( 1 , 1 ) )  
            empty_target_seq[ 0 , 0 ] = sampled_word_index
            states_values = [ h , c ] 
        return "Bot:" +decoded_translation.replace(' end', '')

# %%
def generate_response_english(text):
    # text = input( 'Enter question : ' )
    input_matrix = str_to_tokens_english(text)
    chatbot_response = decode_response_english(input_matrix)
  #Remove <START> and <END> tokens from chatbot_response
    chatbot_response = chatbot_response.replace("<START>",'')
    chatbot_response = chatbot_response.replace("<END>",'')
    return chatbot_response

# %%
generate_response_english('does this have a flip stand')

# %%
questions
# Out:
# ['does it fit nook glowlight',
#  'does this have a flip stand',
#  'does it work with macbook air mid2012',
#  'does this work with mac mini',
#  'does this item come with a charger',
#  'does this nook play games',
#  'does this model have an sd card slot',
#  'can i download the kindle app for this',
#  'can you download netflix',
#  'is it user friendly',
#  'can i play facebook games on it',
#  'can i download the kindle app',
#  'is this compatible with mac os 10.4.11',
#  'can it play games for computer',
#  'does it work with an imac',
#  'will these batteries work in the bushnell range finder',
#  'does the charger work for aa aaa batteries as well',
#  'do you carry this product in white',
#  'will this work in italy',
#  'does it work for a gopro hero',
#  'will this work for the gopro 4 silver',
#  'does the adapter come with sd micro',
#  'can you download save apps in this card',
#  'does it work in other samsung phones',
#  'will this work in a samsung s4 mini',
#  'will this work in a samsung ace 3 s7275',
#  'is possible to use in a m2 slot',
#  'are there different sizes of mini hdmi',
#  'will it work with lg led tv',
#  'will these work in my dcr-trv730 hi8 camcorder',
#  'does this product work 220v electricity grid',
#  'is case included',
#  'does this only work on 110v',
#  'are these headphones compatible with the casio keyboard',
#  'can i use these in my samsung cell phone',
#  'are theses headphones compatible with the yamaha psr320 keyboard',
#  'does this scroll',
#  'is it compatible with the md200tpr',
#  'does it work with motorola ms355r',
#  'would it work fo galaxy s5',
#  'does this work with the motorola ms350r',
#  'does this fit 8mm tapes',
#  'is this compatible with linux',
#  'is this an xr version',
#  'does this unit come with the remote',
#  'does it come with remote',
#  'does this have a pa function',
#  'can you see the rings of saturn',
#  'does it work with different types of mp3 players',
#  'is there a volume control on these headphones',
#  'do these have a mute button inline',
#  'can these receive bluetooth transmissions',
#  'are these noise cancelling headphones',
#  'does this headphone hve a microphone',
#  'does this camera take pictures',
#  'does it includes guarantee',
#  'does it includes guarantee',
#  'are these good headphones for audiobook editing',
#  'is this cable plenum rated for in-wall cable runs',
#  'is there an on off switch on the sensor',
#  'is this digital',
#  'can this be mounted on a wall',
#  'can it take 300 pack film',
#  'does it come with the film',
#  'have you tested it camera already',
#  'is this flash compatible with a pentax k1000 thanks.',
#  'does it play old 8 mm tapes',
#  'is this 35mm',
#  'is it ac dc',
#  'does it come with ear plug',
#  'can u use these with an ipad',
#  'do they fit kids',
#  'does it come with a strap and carrying case',
#  'is this lens for digital cameras',
#  'will it fit eos 10d',
#  'will this fit a 60d',
#  'does this work with canon rebel t2i',
#  'is this compatible to 60d',
#  'would this work with the sl1 a.k.a 100d',
#  'will this work with a canon eos rebel t3i',
#  'will this fit the canon eos rebel t3',
#  'does it have a microphone jack',
#  "can't tell. does it include the remote",
#  'will it fit 1 handlebars',
#  'is it made in the usa',
#  'does this work for semi trucks',
#  'does this pick up marine channels',
#  'will this fit two coaxial cables',
#  'does this eyepiece rotate, if so how much',
#  'is this compatible on my canon t4i camera',
#  'is it compatible with canon rebel t3i',
#  'does this work on the canon sl1',
#  'does this work with the canon rebel xti',
#  'can this bag fit a 7.5 flash standing up',
#  'does it work with 600 ex speedlite flash',
#  'does this fit eos rebel t3 1100d thanks.',
#  'will this work on a canon 6d',
#  'is this camera uses the mini cassette',
#  'can i add an additional light source',
#  'will this lens fit a t5i',
#  'does this lens have image stabilization',
#  'does this fit on the cannon rebel xsi',
#  'does this lens have image stabilization thanks',
#  'does this camera change lens',
#  'does this camera have self-timer function',
#  'does this fit a t-3',
#  'does it work wireless with the canon 60d',
#  'hello, does this works with canon t2i and t3i',
#  'are both ends 3.5 ml. male and female',
#  'would it work with these http www.amazon.com gp product b002...',
#  'is this cable shielded',
#  'is this cable shielded',
#  'will this work with an hp envy 7645',
#  'do they have dual volume control',
#  'does this come with belkins life time warranty',
#  'will this work with a nortel networks phone',
#  'does this work with voip phones',
#  'are all 52mm filters thread compatable',
#  'are all 52mm filters thread compatable',
#  'are all 52mm filters thread compatable',
#  'are all 52mm filters thread compatable',
#  'are all 52mm filters thread compatable',
#  'can i screw a hood over this filter',
#  'can i screw a hood over this filter',
#  'is this a glass filter same as http www.amazon.com tiffen-circular...',
#  'are all 52mm filters thread compatable',
#  'is this a glass filter same as http www.amazon.com tiffen-circular...',
#  'is this a glass filter same as http www.amazon.com tiffen-circular...',
#  'can i screw a hood over this filter',
#  'are all 52mm filters thread compatable',
#  'can i screw a hood over this filter',
#  'are all 52mm filters thread compatable',
#  'is it a glass filter',
#  'is it a glass filter',
#  'are all 52mm filters thread compatable',
#  'is this a glass filter same as http www.amazon.com tiffen-circular...',
#  'can i screw a hood over this filter',
#  'is this a glass filter same as http www.amazon.com tiffen-circular...',
#  'is this a glass filter same as http www.amazon.com tiffen-circular...',
#  'is it a glass filter',
#  'can i screw a hood over this filter',
#  'is this a glass filter same as http www.amazon.com tiffen-circular...',
#  'is this a glass filter same as http www.amazon.com tiffen-circular...',
#  'are all 52mm filters thread compatable',
#  'are all 52mm filters thread compatable',
#  'can it work with my t1i canon',
#  'will this fit a ti2',
#  'will this lens work on nikon d3300',
#  'will this lens work with the nikon d200 thanks',
#  'can i screw a hood over this filter',
#  'does this scope take 2 eyepieces.',
#  'will this work on a nikon d60',
#  'will this lens work with the nikon d5100',
#  'does this lens have image stabilization',
#  'is this lens compatible with the pentax k3',
#  'can it take pictures',
#  'can it record on sd cards',
#  'do u have the remote control its include',
#  'does it with the stylu 740 7.1',
#  'does it work with stylus tough 3000',
#  'does it work with windows vista',
#  'does this one have a surge protector',
#  'does this plug into a usb port',
#  'does this have a battery back-up',
#  'is this card compatible with 2621xm',
#  'is this compatible with a cisco router 1700',
#  'is this suitable for gaming',
#  'do these binoculars come with a case',
#  'does it have presets for stations',
#  'can you preset am radio stations',
#  'will it give grid coordinate',
#  'will this fit for pentax k-5',
#  'will this fit for pentax k-5',
#  'is this lens compatible with my kx',
#  'is this lens compatible with my k x camera',
#  'will this lens fit a pentax q',
#  'will it work with ctk-700',
#  'does it work with casio keyboard ma-150 thanks',
#  'does it play old 8 mm tapes',
#  'does it have image stabilizer',
#  'is this lens compatible with 5d mark iii',
#  'does this lens work with canon t3i',
#  'will this work for my canon vixia hf m40',
#  'will this work with my canon vixia 42 camcorder',
#  'is this lens compatible with a nikon d2h',
#  'will this work with the new d750 fx',
#  'does this work on a d700',
#  'does it af on d600',
#  'is this len work on nikon d600 thanks.',
#  'will it work with a nikon d7100',
#  'will this work with d7000',
#  'is this lens made in japan',
#  'can i use this lense with nikon d600',
#  'will the autofocus work on my nikon d3300',
#  'will it fit a d5300',
#  'is it compatible with a nikon d50',
#  'will this lens auto focus on a d-50 body',
#  'is it compatible with nikon d90',
#  'does this lens work with a nikon d700',
#  'will autofocus work with my d3100',
#  'has anyone tried this lens with a nikon df',
#  'will it work with d700',
#  'will it work with nikon d80',
#  'will this lens work with nikon d3100',
#  'would this len work with a nikon d2x',
#  'will this lens work on the nikon n90s camera',
#  'will this lens work with nikon d70 body',
#  'will this lens work with the d 7000 camera',
#  'will this work for nikon d80',
#  'will it work with d300 camera',
#  'can i use this hard drive for my ps3',
#  'will this drive work for an emachine t4160',
#  'will this work for the edixa-mat reflex',
#  'can be used in a diana f',
#  'is this good with rosetta stone',
#  'do you have to hook it up by usb',
#  'can the mike be place on either side',
#  'does it have a mute button switch on the cord',
#  'does this have a usb adaptor',
#  'does this cb come with the connection box',
#  'is the headband adjustable',
#  'does this speaker require batteries',
#  'is there a spot for cds and dvds',
#  'does it have wifi',
#  'are they rewriteable',
#  'will this lens fit a d5300 dslr',
#  'does it work with canon eos rebel t2i',
#  'is it a sd card user',
#  'does it film at night infrared',
#  'does it play cd-r',
#  'can it be used on a rebel t3',
#  'will this lens fit a canon rebel xsi',
#  'is the camera digital',
#  'is it compatible for canon 50d',
#  'is it compatible for canon 50d',
#  'does it work in a 2005 toyota 4runner',
#  'does this mount work with definitive technology speakers',
#  'is this mount fit with jewel cube speaker',
#  'will this work on a casio lk-30 piano',
#  'is this battery used in sony mvc-cd300 camera',
#  'does it have a low-profile flat wall plug',
#  'does this have the usb to ps2 adapter included',
#  'does this mouse comes with original box',
#  'will the 100 mb drive read 250 mb discs',
#  'will it work on a nikon d3100',
#  'does this mount onto a canon rebel t3i',
#  'will this lens fit rebel xt',
#  'is it not available for the t5i',
#  'will this work with a nikin d40x',
#  'does this lens work on the d90',
#  'will this lens work for the nikon d70',
#  'are these speakers imac compatible',
#  'are these speakers imac compatible',
#  'can this mount on a tripod',
#  'hi, can i connect it to tv',
#  'does it play old 8 mm tapes',
#  'does it have remote control.....',
#  'does this come with a battery charger',
#  'is this a dry cleaner',
#  'will this clean my sony vcr',
#  'will this work with dcr-hc52 sony video cam recorder',
#  'is this cable thx certified thank you.',
#  'is this oxygen free cable',
#  'does it take 8mm tape',
#  'does this gps have sd slot',
#  'does it play dvds and cds',
#  'will this fit a slt102 tripod and head',
#  'does this unit have hdmi in, and how many',
#  'does it have a coaxial digital input',
#  'will this work on novice tasko',
#  'can i get the cable schematic',
#  'is this a pair of brackets',
#  'can these work with a keyhole mount',
#  'is it 60 minutes per side',
#  'is it 60 minutes per side',
#  'is this camera digital',
#  'are speaker grills included',
#  'does this item include the speaker wire',
#  'is case included',
#  'is it black',
#  "does it work with a logitech's wingman formula gp",
#  'will it work with a blue yeti',
#  'can i get a pack of just 1 color',
#  'are these 2.5 male and 2.5 females',
#  'can these labels be used for barcodes',
#  'can this be used in dymo turbo 450 printer',
#  'is the phone full duplex',
#  'will this work for 220 v',
#  'is it safe to plug in a tv',
#  'does this come in the plastic protector case',
#  'is it 3.5mm',
#  'does it work for security cameras',
#  'do they have ubs connection',
#  'how many speaker s are there in each satellite',
#  'can you use with an android phone',
#  'does it come with a power adapter',
#  'does a car charger come with the unit',
#  'does pioner works into bose acosutimass 5',
#  'does pioner works into bose acosutimass 5',
#  'does it works in 220v sockets thank you',
#  'will this unit work on multiline phones system',
#  'will it connect to a his adaptor',
#  'is this cable compatable for the plantronics s11 amplifier headset',
#  'does this head set has noise reduction',
#  'does it have a flat plug',
#  'does this protector have any sound suppression',
#  'can this be wall mounted',
#  'is this a 3 prong surge protector',
#  'will this card work with windows 7 64 bit',
#  'will this card work with windows 7',
#  'will this work with windows 8.1',
#  'is this compatible with a dvi monitor',
#  'is the off on button illuminated',
#  'is there a way to wall mount this unit',
#  'will this handle 5.25 inch floppy disks',
#  'does it support wireless services',
#  'does it have an aux input',
#  'does the scroll wheel stop working',
#  'does this headset require an amplifier',
#  'is this compatible with the panasonic kxtg7431 series',
#  'can this headset be used with an iphone 5',
#  'is this compatible with a cisco ip phone 7962',
#  'will this work with vdsl service from centurylink',
#  'does it have a reset button',
#  'could this usb work for casio graph 65 too',
#  'does this work with ti-84 silver edition',
#  'does this camera work with memory cards',
#  'are these mac compatible',
#  'does this switch include rack mount kit',
#  'can i cut if for a shorter length',
#  'will this work in lenova desktop',
#  'does the order include a pair of speakers',
#  'can connect to receiver by wires not pictured.',
#  'are they wireless',
#  'are they wireless',
#  'do these come with lens caps front and back',
#  'can i connect these speakers to an lg tv',
#  'can i connect with my dvd player',
#  'will this work for a 6d',
#  'will this fit full frame',
#  'will it work on rebel t2i',
#  'will this lens fit my canon rebel t3 dslr',
#  'will this lens fit the canon 60d',
#  'will this lens work with rebel t5',
#  'is this lens good for landscapes',
#  'will this lens fit a canon t5i',
#  'can this camera be hooked to a computer gt',
#  'is this lens made in japan',
#  'is it compatable with d2h firmware 2.1',
#  'will this work with a d3200',
#  'does this work on lens 70-300',
#  'do you ship internationally',
#  'will this fit the nikon - coolpix p520',
#  'does it fit a sony a57',
#  'does it comes with a cap',
#  'does it come with the shotgun mic',
#  'does it support australian maps',
#  'does this card support wake on lan',
#  'can you take videos',
#  'is there a sd card slot',
#  'does it fit a 2002 ford explorer xlt',
#  'will this output hd tv',
#  'can this be used outdoors in the weather.',
#  'does it get power via the cigarette lighter',
#  'does this come with the bracket mount',
#  'does this one have the weather noaa channels',
#  'will this work on a midland cb radio',
#  'is a battery required',
#  'does this set have a rca port',
#  'are these sold by the pair',
#  'are these wireless',
#  'is this one spool of 100 feet of cable',
#  'does this set have a rca port',
#  'does this radio have weather channels',
#  'can they just be ran directly to a reciever',
#  'will they mount a infinity tss 750 satellite speaker',
#  'can you use it also for treadmill',
#  'is this ul certified',
#  'will they mount a infinity tss 750 satellite speaker',
#  'is compatibel celestron nexstar 4 se telescope',
#  'are they wide angle',
#  'are these water fog proof',
#  'does it come with a case',
#  'can this headset be used with cell phones',
#  'is there a remote control include with camera',
#  'is the microphone included',
#  'does this cap work for t3i rebel body',
#  'will it fit a dated eos rebel xt 350d',
#  'does this fit the t5i',
#  'is this the us version and not european',
#  'does light meter show flash percent',
#  'does it come with microfone',
#  'will it work with coolpix p600',
#  'does it work with a canon t2i',
#  'does this remote control the zoom on recording',
#  'is this the wifi capable version',
#  'is this product wi-fi capable',
#  'do these work in hd',
#  "will these cassette's work on our canon xl1",
#  'is this lense compatible with the 10d',
#  'is this lens compatible with the canon rebel t1i',
#  'does it work with canon d600',
#  'does it have a plain, white label',
#  'does this radio work on 200 volts',
#  'does this radio have a cigarette lighter adaptor',
#  'does this radio have an earphone jack',
#  'can this product be used outdoors',
#  'will this work with a lenovo thinkpad yoga',
#  'would this pen work on my surface rt',
#  'does the camera comes with ac adapter',
#  'will these tapes fit into a car stereo',
#  'are these clear',
#  'do these come with clear cases for each one',
#  'are they individually wrapped',
#  'does this camera take the minidv tapes',
#  'is i for toshiba satelite model c55-a5281',
#  'is this compatible with the delphi skyfi 2',
#  'is this compatible with the delphi skyfi 2',
#  'is this compatible with the sirius onyx es',
#  'is there a camera',
#  'can you play minecraft on it',
#  'can you record from tape to dvd',
#  'does it fit on a cp200',
#  'can i use it for the home',
#  'does this work with the rdx series',
#  'does it work w a sp50',
#  'is this a mini dvd',
#  'hello, is this nic compatible with vmware esx 5.1',
#  'is this a low-profile nic',
#  'is camera with it',
#  'is the software mac compatible',
#  'will this printer work with an cannon camera',
#  'will my easyshare cx6330 camera work with this',
#  'does it work with a kodak v1073 camera',
#  'does this come with the power cord',
#  'does the model allow for port triggering',
#  'does this camera have a light meter',
#  'does this camera have a light meter',
#  'will a standard security loop fit through the slot',
#  'are these slim',
#  'is the dc plug included',
#  'is this voice activated',
#  'can i use this with time warner cable internet',
#  'will it work with usb 2.0',
#  'does this sub support 230v, 50hz',
#  'is this 240v please',
#  'does exist in 220v',
#  'will these work on a kindle fire hdx',
#  'can i use this flash on my canon camera',
#  "can you burn cd's",
#  'will this work on a cybershot dscp100',
#  'does this work with sony cybershot dsc-s780',
#  'will this work with a avchd progressive',
#  'do these speakers come with direct burial speaker wire',
#  "are therse speaker's price for 2 of them",
#  'does this work with chromebooks',
#  'does this microphone work with windows 7 professional',
#  'does this have phono inputs',
#  'is it also compatible with windows 7',
#  'can i screw a hood over this filter',
#  'is the on off switch lighted',
#  'does this have a wall mount option',
#  'does this connect to a cell phone',
#  'is this compatible with the nikon d300',
#  'is this compatible with the nikon d5100',
#  'does vr works nikon d800',
#  'will this work in an elonex exentia',
#  'can i use these speakerswith only an ipad',
#  'can you control the volume',
#  'will this item can control pioneer avic-8000nex flagship',
#  'does it come with all the wiring, remote,etc',
#  'do these come with speaker grills',
#  'are these water proof',
#  'does the pioneer cassette also include a radio',
#  'is this filter for sigma 35 mm 1.4',
#  'is this filter for sigma 35 mm 1.4',
#  'does this work on a 7d',
#  'will this work with my canon rebel t3',
#  'will this work with the canon rebel t4i',
#  'will it work with nexstar se 6',
#  'will it work for a nikon d80',
#  'will this work with sx260 hs',
#  'does this work on aps-c cameras',
#  'does it come with tripod mount',
#  'does this work with my eos rebel t5i body',
#  'does this lens come with a tripod collar',
#  'will this fit my nikon d5300',
#  'will this cap fit the d80',
#  'does this product work with a d3300',
#  'does it work with nikon d7100',
#  'is the plastic and papre acid free',
#  'are the sheets archival quality',
#  'is for 220v',
#  'can this lense be used with the nikon 3200',
#  'will the plug on these work on airplanes',
#  'do these come with a case',
#  'will this fit the sony cx-230 handycam',
#  'can this hold ps4 games',
#  'does this come with a bag',
#  'does this tripod have a fluid pan',
#  'will this fit my 7000tm tripod',
#  'is it compatible with 8mm video cassette',
#  'will this work for mini cassette tapes',
#  'will this work with vivitar-240',
#  'is this plate fit on vivitar vpt 360 tripod',
#  'does this work on canon 50d tia',
#  'are the pages archival and acid free',
#  'can this work with a zeikos grip',
#  'would this fit my nikon d7100',
#  'does it fit 2006 saab 9-5 with navigation system',
#  'is it work with gm trialblazer 2006',
#  'will this fit the velbon victory 150',
#  'would the lens fit on a fujifilm xm1',
#  'is it black and white',
#  'can you use this for home made pinhole photography',
#  'is the lens has scraches',
#  'is this lens good for portraits',
#  'does this work with d60',
#  'do you ship to new zealand',
#  'will this lense work with my d5300 and d3200',
#  'will this lens work with a d700',
#  'will this lens work with the nikon f100',
#  'can i get an owners manual in english',
#  'do work in taiwan',
#  'how long is the cable amp is it detachable',
#  'is it fit for compact 85-lumen pocket projector',
#  'does it work with optoma ml550 projector',
#  'is this a wireless speaker',
#  'is the recording side black as well',
#  'are these focus free',
#  'does this support packet injection',
#  'is this compatible with arca-swiss',
#  'will it work work with 5d mark iii 6d',
#  'does this also work on the 5d mark 3',
#  'is this lens work with canon t3i',
#  'will this work on my 70-200mm lens',
#  'will this work for a celestron nexstar evolution 8',
#  'does it come with a carousel',
#  'does it mount onto tamron 70-200 for nikon',
#  'does it come with a case',
#  'does it come with a neck strap',
#  'do these come with a case',
#  'is there a compass on these',
#  'is there an internal rangefinder in these binoculars',
#  'does it come with a carrying bag',
#  'does this come with a case',
#  'would these be good binoculars for hunting',
#  'would these work for plane spotting at low high altitudes',
#  'does this come with a case',
#  'will this work on the nikon d90',
#  'will this lens work on a d7000',
#  'will this lens work on a canon 50d',
#  'does this cable work on the coolpix s3300',
#  'will it work on a coolpix s6100',
#  'will this cable work for a cool pix l24',
#  'does it come with the keyboard and screen',
#  'can i use this to pick up wireless internet',
#  'does this headset have volume control',
#  'can you use it with an ipad',
#  'does this work with the ef 75-300 f-stop 4-5.6',
#  'does this work with the ef 75-300 f-stop 4-5.6',
#  'can you hang these on the wall',
#  'can u put photos in both sides',
#  'can additional sheets be added this binder',
#  'does it work for 35mm negatives',
#  'can this be hung on a wall',
#  'can this be mounted',
#  'does this have a flat plug',
#  'will it power a cpap machine',
#  'do these binoculars come with a case',
#  'i am wearing glasses, can i use this binos',
#  'will this work with the fujifilm instax 210 camera',
#  'will it fir cannon 40d eos',
#  'does this mic come with an xlr cable',
#  'can extra belt clips be ordered',
#  'does this product come with the charger',
#  'will it work with a mag one bpr40',
#  'does this tool works on cat 6',
#  'will this work in an e-machines t3302',
#  'would this work with a westcott td5',
#  'will this lens autofocus autoexposure with the nikjon d800',
#  'is this a fx lens',
#  'will this work on my humminbird wide vision',
#  'would this transfer audio as well',
#  'does it take a standard nikon 52mm lens cap',
#  'will this filter work on a nikon 5200 camera',
#  'will this fit the nikon 18-200mm lens',
#  'will this film work in a revere model 88',
#  'does it work with nikon lens',
#  'is the bottom well padded',
#  'is the bottom well padded',
#  'does this fits fuji mini 90',
#  'can you look at the photo before it prints',
#  'is this film for the fujifilm instax 210',
#  'can i use this film for polaroid one step',
#  'can this camera record video and sound',
#  'does this camera take video',
#  'does it take good action shots',
#  'can this camera record video and sound',
#  'does this camera take video',
#  'does it take good action shots',
#  'does it work with a ti3',
#  'will this adaptor will work with my sony dsc-s85',
#  'does this have the dustcover and 45 adapter',
#  'does this camera have a flash',
#  'does this work on windows 8',
#  'does your product have the crosley monogram',
#  'do the speakers connect with wires',
#  'does it have fm am radio',
#  'do this come with a hdmi plug',
#  'can you stack this one with the 25mm',
#  'will video game cases fit in these',
#  'does this battery fit in the dx 7590 camera',
#  'can i get extra cd cartridges',
#  'will device work on a dell gx270 and gx280',
#  'does this lens auto-focus',
#  'does this lens have autofocus',
#  'will this lens work with the olympus e-520',
#  'will this work on a 5d',
#  'will this work with the canon t5i',
#  'does the apple have wifi be honest',
#  'hello. is this laptop wireless and wifi ready',
#  'can you store pictures on an ibook',
#  'will it facetime',
#  'can you play online games',
#  'is the tripod included',
#  'does it come with the tripod',
#  'will this work with my eos 700d rebel t5i',
#  'is the device compatible with a powered usb hub',
#  'is this a real dual link dvi cable',
#  'does this telescope come with an alt az mount',
#  'does this fit the orion xt8 dobson telescope',
#  'can this work on any orion',
#  'will this work with my orion goscope',
#  'can you see saturn and jupiter in full detail.',
#  'does it include a bag to carry the equipment',
#  'is it water proof',
#  'will this lens fit on my d7000',
#  'will this work with nikon d80',
#  'can this system be used with hd tv',
#  'can i use this oversea with 220v',
#  'will it hold a battery for canon 60d',
#  'do the headphones have a volume control',
#  'does this headphone has microphone in it',
#  'will this sonically pair with these in walls http www.amazon.com gp product b000...',
#  'can you sent me a picture this camera',
#  'does a mini dv video cassette fit into this',
#  'will this work with kodak 8mmp6-120',
#  'will a mini dv tape fit into this adaptor',
#  'is it a cassette player',
#  'would it fit my ford escape 2003',
#  'will it fit on a 2000 toyota camery',
#  'does this radio cd reads and plays homemade cd',
#  'can you use phones bluetooth with the dual xdm7617',
#  'can you use phones bluetooth with the dual xdm7617',
#  'will it fit a 95 toyota camry',
#  'is there a subwoofer out',
#  'does it have front to rear fade',
#  'would you consider shipping to new zealand',
#  'does this lens work with the nikon d3200',
#  'will the autofocus work on my nikon d3300',
#  'does this lens include the front and rear caps',
#  'does this work with the ef-s mount',
#  'does this len fit a canon eos rebel 1000d',
#  'does this fit on a 480 camcorder',
#  'does this fit on logitech c920 web camera',
#  'will this work with the star mate 5 radio',
#  'has some accssesorie',
#  'can sd card be used',
#  'will this cable connect hp laserjet 5mpto windows 8',
#  'does this work with the ef-s mount',
#  'does this len fit a canon eos rebel 1000d',
#  'are these really 23.2 inches long',
#  'does it play old 8 mm tapes',
#  'hello, will this camera playback 8mm video tapes thanks',
#  'would a hf g30 fit well in this case',
#  'will this work for the canon xa25',
#  'does this camera come with the a v cable',
#  'are they bak4',
#  'do these have a detachable cable',
#  'will this bag fit a 17.3 laptop',
#  'is it compatible with kodak camera dx 7630',
#  'does this work on a canon 40d',
#  'can this be used on a eds 30d',
#  'does this come with a lens hood',
#  'is it compatible with kodak camera dx 7630',
#  'is this a true canon battery',
#  'does this sony slv-n750 play betamax tapes',
#  'can you record from the dvd to vcr',
#  'can you record from the vcr to the dvd',
#  'does a carrying case come with this product',
#  'is this cord compatible with nikon d40 camera',
#  'can you deliver to overseas france',
#  'is it windows 8 compatible',
#  'would these binos be good for theatre',
#  'will this fit the montana',
#  'does it become wireless',
#  'will this tripod work for my sony a6000',
#  'does it come with a case',
#  'is the interpupillary distance adjustable',
#  'is this a noice cancelling headset',
#  'i wear hearing aids, is it compatible with them',
#  'will this headset work on a computer',
#  'will 14 gauge wire be better than 16 gauge',
#  'are these wireless',
#  'are these speakers paintable',
#  'does it work on the nikon d3000',
#  'will this lens fit the canon eos rebel t3i',
#  'does this work with the ef-s mount',
#  'does this len fit a canon eos rebel 1000d',
#  'does it work on the nikon d3000',
#  'will this lens fit the canon eos rebel t3i',
#  'will this fit the nikon 18-140mm lens',
#  'does this cable have a male and female end',
#  'is this price for a pair',
#  'can i record a show, erase and record again',
#  'do the disks each come with a case',
#  'will this fit my d3100',
#  'will this lens work on the d3000',
#  'will this adapter work with windows 2000',
#  'can i plug it in',
#  'does it stand up on its own',
#  'does this lens have image stabilization',
#  'is it compatible with the canon rebel t1i',
#  'will this lens fit my d90 nikon digital',
#  'can it ride on top of suitcase',
#  'would it fit 2 laptops',
#  'is this model ssvc-6, part fg01044',
#  'do these fit 2002 ford ranger',
#  'can be connected to a amplifier',
#  'are these coaxial speakers',
#  "has anyone verified these speakers' rating of 200w rms",
#  'is thare a low profile mount',
#  'is this made with copper wire',
#  'is this made with copper wire',
#  'can these be used for rear speakers',
#  'can this used with a hp envy charger',
#  'will it fit a dell inspirion adaptor',
#  'will this work on a cannon t3i',
#  'does this adapter work with the nikon d5200',
#  'will it work on a nikon d5200',
#  'does this phone have a mute button',
#  'does this fixative work on charcoal',
#  'will this work on an xbox one controller',
#  'would these speakers work with my sirius xm sd2 dock',
#  'does each speaker have independent volume control',
#  'does it have a speaker jack',
#  'does this camera work well in low light',
#  'do this camera have a memory card slot',
#  'does it record in high definition',
#  'can i use this with a guitar',
#  'does this disk work for the handycam dcr-dvd203 model',
#  'is this compatible with toshiba model sp416 tecra a5',
#  'does this unit have outputs for recording',
#  'is this for compaq presario v5000 v5305wm',
#  'does it come with mounting hooks',
#  'is this a translator for spanish and other languages',
#  'does this detector have a jack for headphones.',
#  'can you put photos on these',
#  'can you put photos on these',
#  'do i need to purchase speakers',
#  'can you hook headphones into this one',
#  'can this fit a kenwood kdc-bt562u',
#  'will it fit 2000 chevy silverado thanks',
#  'does this fit 2002 chevy silverado',
#  'does it fit a 1999 chevy astro van',
#  'does it work with canon powershot',
#  'is this phone nortel extension compatible',
#  'can i get power adapter with this',
#  'does the screen come with tripod',
#  'is there a fan in this unit',
#  'can this be used to check out car stereo',
#  'will this fit a 97 toyota 4runner',
#  'will these work for ceiling mounting',
#  'are they compatible for speakers with the keyhole connection',
#  'do there tweeters have replacement coils',
#  'will this fit a 2008 chevy equinox',
#  'does this work on a 2001 s10',
#  'will this fit a 2001 chevy metro',
#  'will this fit my 02 chevy s10',
#  'will it fit in my honda accord 1996 ex',
#  'will it work for acura integera 1995 ls',
#  'will it fit a 2005 pontiac grand am',
#  'will these fit a 1996 chevy 1500c',
#  'will these work for the rear speakers as well',
#  'does it work in a 2008 mazda 6i',
#  'does this include the screws',
#  'will it work in a 1985 nissan 300zx',
#  'does this fit 2003 ford mustang base convertble',
#  'will this fit my 2003 ford escape xlt',
#  'does this fit an 02 f250',
#  'does it work for the honda odyssey 2004',
#  'does work with my honda pilot 2005',
#  'will this fit my 2005 gto',
#  'will this a fit 2003 dodge ram 2500',
#  'is their a wire for the dimmer switch',
#  'is the plug angled',
#  'is this strip ul listed',
#  'is the cord grey, black or green',
#  'is the write support removable',
#  'can this replace the optical mouse 2000',
#  'will it fit a 1998 toyota 4runner',
#  'will this fit a 2004 chevy tahoe',
#  'can this replace the optical mouse 2000',
#  'does this telescope come with a carrying case',
#  'is this surge protector ul listed',
#  'have spare membranes',
#  'will this work for an avaya 5410',
#  'can this be used to clean polarized sunglasses',
#  'will these fit an 4g ipod',
#  'will this work for the dime distortion pedal',
#  'would this work for the darkglass electronics b7k',
#  'will this work with an alesis sr-16 drum machine',
#  'can you record multiple tracks using audacity software',
#  'does this preamp come with a power cord',
#  'does this item come with the shock mount',
#  'will this work with samsung galaxy siii thank you',
#  'does it pan smoothly enough for video',
#  'is it easy to roll back up',
#  'does this unit come with a remote control',
#  'can you connect a powered sub to this unit',
#  'does this tripod include a carrying bag',
#  'does it come with release plate',
#  'does it work on arabsat',
#  'does it fit the cr8005a turntable',
#  'will this work on my jenson player',
#  'will it fit my jensen jta-460 model',
#  'would this work with a fisher mt-223',
#  'will this fit a player purchased from urban outfitters',
#  'will this fit a studebaker sb6051',
#  'will this work with a canon 7d',
#  'are the light bulbs included one purchaser said not',
#  'is there a solid base',
#  'does it come with surge protector',
#  'will this work with win 7',
#  'can the nvmt connect to all guns',
#  'can the nvmt connect to all guns',
#  'does this cable fit canon a-1',
#  'does this product come with bulbs',
#  'can you put these over hearing aids',
#  'does this work with the ef-s mount',
#  'does this len fit a canon eos rebel 1000d',
#  'is this v3',
#  'will this work to hook up ooma wirelessly',
#  'is this compatible with a macbook air 2013',
#  'does this monitor have ips',
#  'does it have its own speakers',
#  'can you use it overseas with 220v',
#  'will this work for 06 denali serria',
#  'does this phone feature 5 outside lines',
#  'can you transfer calls',
#  'will this fit my philips cassette player az1018',
#  'is this a 120v',
#  'is the output at least dolby 5.1',
#  'would this work with a tablet',
#  'does it have a car plug in',
#  'can i used this to power my car amp',
#  'are the usb cables included with this switch',
#  'can i use it in country with 220v electricity',
#  'does it come with a remote control',
#  'do you get sorround sound gt gt',
#  'will this work to connect a wireless microsoft mouse',
#  'is this bluetooth 4.0',
#  "does it work with samsung's smart tvs",
#  'will it fit under the seat in an airplane',
#  'does it come with battery',
#  'does it need battery, what size',
#  'do it have back lit display',
#  'are these sold in pairs',
#  'does this ship with the fuse as pictured',
#  'does it have a mounting tab',
#  'is this rated up to 3ghz',
#  'can i use this with yamaha rx373 receiver',
#  'does it come with the 4 aa batteries',
#  'does this charger have universal 110-240 current capabilities',
#  'can i use this with yamaha rx373 receiver',
#  'does it come with its wall power suply adapter',
#  'is this 2gb - 2x1gb modules',
#  'can i use this on my sony home receiver',
#  'will this lens work on a canon rebel xsi',
#  'will this lens work on a canon t3i camera',
#  'will this lens work on a canon rebel xsi',
#  'will this lens work on a canon t3i camera',
#  'will this lens work on a canon rebel xsi',
#  'will this lens work on a canon t3i camera',
#  'will this lens work on a canon rebel xsi',
#  'will this lens work on a canon t3i camera',
#  'is this a military scanner',
#  'is it digital',
#  'does this fit an apc be750bb',
#  'can the headset be used with the ipad',
#  'is the surge protector mountable',
#  'is it made in china',
#  'will it fit a sony a3000',
#  'can i use in my gopro',
#  'does this come with ear buds',
#  'is it mp3 capable',
#  'are rack mounts included',
#  'does this player have a headphone jack',
#  'does this player have an earphone jack',
#  'does it need a certain type of cassette',
#  'does it have a manual and automatic mode switch',
#  'can i use this with a tamorn lens',
#  'will this work on a d600',
#  'will this work with a nikon d5100',
#  'would this viewfinder fit on nikon d5000',
#  'can you change the shutter speed on this camera',
#  'does this radio come with an earpiece',
#  'could you fit an ipad mini',
#  'does this lens fit canon rebel t3',
#  'will this lens fit a canon 60d',
#  'is this lens capable of macro shots',
#  'does this case come with a shoulder strap',
#  'does it work for whammy 5',
#  'do they have a mic',
#  'will this work with windows 8.1',
#  'does it work on windows 8.1',
#  'does it come with a remote',
#  'can i hook up bose wi-fi',
#  'does it have a shuffle feature',
#  'does this card work with windows 7 64bit',
#  'does this work on a 2004 trailblazer',
#  "does this play 78lp's",
#  'does this work for the escort 9500 ix',
#  'will it work on a cobra',
#  'will it work with solo 2',
#  'will it fit my 1995 f150 pickup',
#  'does this keyboard work with the palm tx',
#  'will it work on kindle fire hd',
#  'does this support bluetooth',
#  'will this fit a 2001 cavalier without onstar',
#  'will this fit a 2002 silverado lt',
#  'will this work on a factory amped 2000 suburban',
#  'will this fit a 2000 astro',
#  'will this fit a 2002 lesabre',
#  'is this scanner digital',
#  'is up to date',
#  'will this camera body take a 35mm lens',
#  'is this one 19 in width',
#  'are they compatible with amazon kindle fire',
#  'is this will work for ipad computer mp3',
#  'is it volume-controlled',
#  'can it be used outdoors',
#  'is the cord included as it shows the cord',
#  'would this work on pentax k10d',
#  'would this work on pentax k10d',
#  'would this work on pentax k10d',
#  'would this work on pentax k10d',
#  'does this radio have a sleep timer setting',
#  'is this compatable with the powershot elph 300',
#  'will this work on p-a688',
#  'does this radio have a wall plug',
#  'can use for canon 5d mark 2',
#  'will this work with nikon d3000',
#  'is this fan quiet',
#  'is this fan a 12v',
#  'does it come with a vented bezel plate',
#  'does this drive come with the caddy',
#  'is this a new unused drive',
#  'are these 8 ohm rated',
#  'is this price for a pair',
#  'do the speakers have volume control',
#  'does this come with speaker wire',
#  'is it work with optoma hd26',
#  'will it work for benq 1070',
#  'is this battery compatible with the casio exilim ex-z77',
#  'does this battery work for casio exilim ex-2850',
#  'will this work for casio exilim ex-275 camera',
#  'can it record to a disc instead of tape',
#  'does this camera use an sd card',
#  'does this record on tapes',
#  'will this amp push more than four speakers',
#  'can i use it to play with my 3ds',
#  'does it work on the nikon d3000',
#  'will this lens fit the canon eos rebel t3i',
#  'does this have its own driver thx',
#  'does this siren have its own driver',
#  'do these speakers include the equalizer',
#  'is it compatible with espson tm-u220b model m188b',
#  'does it hold 8mm tapes',
#  'does this work for sony mini dv lp-90 cassette',
#  'is there a home docking station',
#  'do these stick to painted wood',
#  'does this monitor have hd sdi in',
#  'does it work with a canon 3ti',
#  'does it fit the pen e-pl 1 camera',
#  'will this lens fit the evolt e-300',
#  'will this fit work fully with the e-410 body',
#  'can you stack records on this player',
#  'does it have a mp3 hookup also',
#  'do these fold at all',
#  'will these work in an ipad',
#  'would you sell just the bass module subwoofer',
#  'is this a hdmi hookup',
#  'are the speakers wireless',
#  'does this work with the ipod classic',
#  'does this work with an iphone 4',
#  'will this work with polycom soundstation 300',
#  'will these work with the 2200-16200-001',
#  'will these work with polycom soundstation 2w, part 2201-67880-022',
#  ...]

# %%
def predict_language(text):
    lang = pipe.predict([text])
    return(lang[0])
def final_response(message):
    
    if((predict_language(message)=="English")):
        #we predict first the intent(the class) from the message
        return(generate_response_english(message))
    else :
        return(generate_response(message))

# %%
final_response(" البلوزه رقم 21 كم سعرها")

# %%
from flask import Flask, render_template, request, redirect, url_for,jsonify
from flask_ngrok import run_with_ngrok

app = Flask(__name__, static_url_path='/static') 
run_with_ngrok(app)

@app.route("/",methods=["get"])
def home():
    return render_template("index.html")
@app.route('/predict',methods=["Post"])
def predict():
    text = request.get_json().get('message')
    response = final_response(text)
    message ={"answer" : response}
    return jsonify(message)
app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [24/Oct/2022 18:22:45] "GET / HTTP/1.1" 200 -
#  * Running on http://0d3f-197-46-84-209.ngrok.io
#  * Traffic stats available on http://127.0.0.1:4040
# 1/1 [==============================] - 1s 1s/step
# WARNING:tensorflow:Model was constructed with shape (None, 80) for input KerasTensor(type_spec=TensorSpec(shape=(None, 80), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'"), but it was called on an input with incompatible shape (None, 1).
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 127.0.0.1 - - [24/Oct/2022 18:22:53] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 1s 980ms/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 127.0.0.1 - - [24/Oct/2022 18:23:21] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 18ms/step
# 127.0.0.1 - - [24/Oct/2022 18:24:19] "POST /predict HTTP/1.1" 200 -
# [2022-10-24 18:25:46,781] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_2492/4047516892.py", line 13, in predict
#     response = final_response(text)
#   File "C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_2492/1539107625.py", line 8, in final_response
#     return(generate_response_english(message))
#   File "C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_2492/4166804970.py", line 3, in generate_response_english
#     input_matrix = str_to_tokens_english(text)
#   File "C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_2492/557640828.py", line 7, in str_to_tokens_english
#     tokens_list.append( tokenizer_english.word_index[ word ] )
# KeyError: 'sondos'
# 127.0.0.1 - - [24/Oct/2022 18:25:46] "POST /predict HTTP/1.1" 500 -
# [2022-10-24 18:26:03,031] ERROR in app: Exception on /predict [POST]
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\ProgramData\Anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_2492/4047516892.py", line 13, in predict
#     response = final_response(text)
#   File "C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_2492/1539107625.py", line 10, in final_response
#     return(generate_response(message))
#   File "C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_2492/472190316.py", line 3, in generate_response
#     input_matrix = str_to_tokens(text)
#   File "C:\Users\MOHAME~1\AppData\Local\Temp/ipykernel_2492/1212807458.py", line 7, in str_to_tokens
#     tokens_list.append( tokenizer.word_index[ word ] )
# KeyError: 'التيشرت'
# 127.0.0.1 - - [24/Oct/2022 18:26:03] "POST /predict HTTP/1.1" 500 -
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 11ms/step
# 127.0.0.1 - - [24/Oct/2022 18:26:15] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 127.0.0.1 - - [24/Oct/2022 18:26:40] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 127.0.0.1 - - [24/Oct/2022 18:26:55] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 127.0.0.1 - - [24/Oct/2022 18:27:09] "POST /predict HTTP/1.1" 200 -
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 127.0.0.1 - - [24/Oct/2022 18:27:27] "POST /predict HTTP/1.1" 200 -
